# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#获取基金费率等信息" data-toc-modified-id="获取基金费率等信息-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>获取基金费率等信息</a></span></li><li><span><a href="#获取基金经理信息" data-toc-modified-id="获取基金经理信息-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>获取基金经理信息</a></span></li><li><span><a href="#获取基金规模，年度收益信息" data-toc-modified-id="获取基金规模，年度收益信息-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>获取基金规模，年度收益信息</a></span></li><li><span><a href="#获取多只基金的信息" data-toc-modified-id="获取多只基金的信息-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>获取多只基金的信息</a></span></li><li><span><a href="#相关阅读" data-toc-modified-id="相关阅读-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>相关阅读</a></span></li></ul></div>

# %%
import pandas as pd
import datetime
import numpy as np
import tushare as ts
import os
import time

print(f'tushare version: {ts.__version__}')
print(f'pandas version: {pd.__version__}')
print(f'numpy version: {np.__version__}')
# Out:
# tushare version: 1.2.84
# pandas version: 1.4.1
# numpy version: 1.22.3

# %% [markdown]
# 使用tushare 获取财经数据，首先需要注册，注册地址如下：
#
# [点击注册tushare](https://tushare.pro/register?reg=129033)
#
# 然后按照下面的代码设置 token
#
# 以上方法只需要在第一次或者token失效后调用，完成调取tushare数据凭证的设置，正常情况下不需要重复设置。

# %%
# token='XXXXXXX'  
# ts.set_token(token)

pro = ts.pro_api()

# %% [markdown]
# ## 获取基金费率等信息

# %%
# 获取基金中文名称信息
df_e = pro.fund_basic(market='E')
df_o = pro.fund_basic(market='O')
# df_fund_info = df_e.append(df_o)
df_fund_info = pd.concat([df_e,df_o])
df_fund_info = df_fund_info[['ts_code','name', 'management','m_fee', 'c_fee','found_date']]
df_fund_info.columns = ['fund_code','fund_name', 'management','m_fee', 'c_fee','found_date']
df_fund_info = df_fund_info.reset_index(drop=True)
df_fund_info
# Out:
#         fund_code   fund_name management  m_fee  c_fee found_date
# 0       508018.SH  华夏中国交建REIT       华夏基金   0.10   0.01   20220413
# 1       159618.SZ     光伏ETF华安       华安基金   0.50   0.10   20220408
# 2       501217.SH     行业配置FOF       华夏基金   0.80   0.20   20220408
# 3       513530.SH    港股通红利ETF     华泰柏瑞基金   0.50   0.10   20220408
# 4       517760.SH    消费TOPETF     浦银安盛基金   0.50   0.10   20220401
# ...           ...         ...        ...    ...    ...        ...
# 16625   000198.OF       天弘余额宝       天弘基金   0.30   0.08   20130529
# 16626  4710071.OF    汇添富理财7天A      汇添富基金   0.27   0.08   20130529
# 16627   000117.OF      广发轮动配置       广发基金   1.50   0.25   20130528
# 16628   000082.OF     嘉实研究阿尔法       嘉实基金   1.50   0.25   20130528
# 16629   000143.OF     鹏华双债加利A       鹏华基金   0.50   0.15   20130527
#
# [16630 rows x 6 columns]

# %% [markdown]
# ## 获取基金经理信息

# %%
# 获取单个基金的信息

def get_fund(fund_code,df_fund_info):    
    # 获取基金经理信息，以及开始管理该基金的日期
    df_manager = pro.fund_manager(ts_code=fund_code)
    df_manager = df_manager[df_manager['end_date'].isna()]
    df_manager = df_manager.sort_values('begin_date',ascending=True).head(1)
    begin_date = df_manager['begin_date'].values[0] # 开始管理该基金的日期
    df_manager = df_manager[['ts_code', 'name', 'gender','begin_date']]
    df_manager.columns = ['fund_code', 'manager_name', 'gender','begin_date']
    
    # 合并
    df_fund = pd.merge(df_manager,df_fund_info,how='left',on='fund_code')

    return df_fund

# %%
# 110011.OF,易方达优质精选
df_fund = get_fund('110011.OF',df_fund_info) 
df_fund
# Out:
#    fund_code manager_name gender begin_date fund_name management  m_fee  \
# 0  110011.OF           张坤      M   20210910   易方达优质精选      易方达基金    1.5
#
#    c_fee found_date
# 0   0.25   20210910

# %% [markdown]
# ## 获取基金规模，年度收益信息

# %%
# 获取单支基金的年度收益,基金规模等信息

def get_returns(fund_code,start_year):
    """获取单支基金的年度收益,基金规模等信息
    Keyword arguments:
    fund_code -- 基金代码，如：110011.OF
    start_year -- 开始获取基金数据的年份
    """
    df_fund_nav = pro.fund_nav(ts_code=fund_code)
    df_fund_nav['date'] = pd.to_datetime(df_fund_nav['nav_date'])
    df_fund_nav = df_fund_nav.set_index('date').sort_index()
    
    years = df_fund_nav['accum_nav'].resample('AS').sum().to_period('A')
    # 获取年度数据，类型为 pandas 的 period
    years = years.index.tolist()
    
    # 有些基金的开始日期晚于2018年，需要对齐列，补空白
    year_list = [yr.year for yr in years if yr.year>=start_year]
    
    # 将 period 时间数据转为 string 的年度数据
    years = [str(yr.year) for yr in years]

    df_yrs_index = pd.DataFrame()
    for yr in years:
        df_yr_index = df_fund_nav.loc[yr].tail(1)
#         df_yrs_index = df_yrs_index.append(df_yr_index) # append 将被替代
        df_yrs_index = pd.concat([df_yrs_index,df_yr_index])
#     df_yrs = df_fund_nav.head(1).append(df_yrs_index)
    df_yrs = pd.concat([df_fund_nav.head(1),df_yrs_index])

    # 计算每年的收益率，即涨跌幅度
    df_yrs['returns'] = df_yrs['accum_nav'].pct_change()

    # 删除收益率为 NA 的行 （第1天有数据记录的日期）
    df_yrs = df_yrs.dropna(subset=['returns'])

    # 筛选自开始年份以来的数据
    df_yrs = df_yrs.loc[str(start_year):]

    df_yrs = df_yrs.reset_index()
    df_yrs['year'] = df_yrs['date'].dt.year

    # 透视表
    df_yr_returns = pd.pivot_table(
        df_yrs, index=['ts_code'],
        values=['returns'], columns=['year'], fill_value=""
    )

    # 将多层索引转变为单层索引
    df_yr_returns = df_yr_returns['returns']
    df_yr_returns = df_yr_returns.reset_index()
    df_yr_returns.columns.name = None
    
    df_yr_returns = df_yr_returns.rename(columns={'ts_code':'fund_code'})
    
    # 基金份额
    df_fund_share = pro.fund_share(ts_code=fund_code).head(1)
    df_fund_share.columns = ['fund_code', 'fd_share_date', 'fd_share', 'fund_type', 'market']
    # fd_share,单位是 万份
    fd_share_date = df_fund_share['fd_share_date'].values[0] # 份额对应的日期
    
    # 份额日期的净值数据
    df_ann_nav = df_fund_nav.loc[fd_share_date:fd_share_date].sort_values('update_flag',ascending=False).head(1)
    df_ann_nav = df_ann_nav[['ts_code', 'accum_nav','unit_nav']]
    df_ann_nav.columns = ['fund_code', 'accum_nav','unit_nav']
    
    # 计算基金规模，amount，单位：亿元
    df_fund_amount = pd.merge(df_fund_share,df_ann_nav,how='left',on='fund_code')    
    df_fund_amount['amount'] = df_fund_amount['fd_share'] * df_fund_amount['unit_nav']/10000
    df_fund_amount = df_fund_amount[['fund_code','amount','fd_share_date']]
    
    # 合并数据    
    df_yr_returns = pd.merge(df_fund_amount,df_yr_returns,how='left',on='fund_code')

    for yr in year_list:
        if yr not in df_yr_returns.columns.tolist():
            df_yr_returns[yr]=np.nan
    
    return df_yr_returns

# %%
df_return = get_returns('110011.OF',2018)
df_return
# Out:
#    fund_code     amount fd_share_date      2018      2019      2020      2021  \
# 0  110011.OF  216.61701      20210930 -0.129849  0.585684  0.715145 -0.108154
#
#        2022
# 0 -0.160545

# %% [markdown]
# ## 获取多只基金的信息

# %%
# 获取多只基金的信息

def get_data_fund(df_fund_info,fund_code_short,start_year):
    df_filter_info = pd.DataFrame()
    for code in fund_code_short:
        df_tmp = df_fund_info[df_fund_info['fund_code'].str.contains(code)].head(1)
#         df_filter_info = df_filter_info.append(df_tmp)
        df_filter_info = pd.concat([df_filter_info,df_tmp])
    df_filter_info = df_filter_info.reset_index(drop=True)   
    fund_codes = df_filter_info['fund_code'].tolist()
    # fund_codes

#     df = pd.DataFrame()
    frames = [] # 用来装载 df_fund_merge
    i=0
    for code in fund_codes:
        print(f'i:{i},code:{code}')
        if i<78:
#             print(code)
#             print(f'i:{i},code:{code}')
            df_fund = get_fund(code,df_fund_info)    
            df_return = get_returns(code,start_year)
            df_fund_merge = pd.merge(df_fund,df_return,how='left',on='fund_code')
            frames.append(df_fund_merge)
            i +=1
        else:
            i=0
            time.sleep(61)
#         df = df.append(df_fund_merge)
    df = pd.concat(frames)
    df = df.reset_index(drop=True)
    
    df = df.rename(columns={
        'fund_code':'基金代码','manager_name':'基金经理',
        'gender':'性别','begin_date':'上任日期',
        'fund_name':'基金名称','management':'基金公司',
        'm_fee':'管理费','c_fee':'托管费',
        'found_date':'成立时间','amount':'基金规模(亿元)',
        'fd_share_date':'规模对应日期'
    })
    
    # 调整列的排序
    cols = df.columns.tolist()
    col_1 = cols[:4]
    col_2 = cols[4:5]
    col_3 = cols[5:]
    cols = col_2 + col_1 + col_3
    df = df[cols]

    return df

# %% [markdown]
# 设置具体的参数

# %%
# 需要获取的基金代码简称列表
fund_code_short = ['001938', '162605', '005911', '005827','007119', 
                   '110011', '161005', '000800', '519736', '163402',
                   '003095', '163406', '002190', '164908', '000772']

# 设置基金收益开始的年份
start_year = 2018
# 设置基金收益截止的年份
end_year = 2022
year_list = list(range(start_year,end_year+1))

df_fund_final = get_data_fund(df_fund_info,fund_code_short,start_year)
df = df_fund_final.sort_values('基金经理',ascending=True,ignore_index=True)
# df.to_csv('./data/fund_manager.csv',index=False)
df
# Out:
# i:0,code:001938.OF
# i:1,code:162605.SZ
# i:2,code:005911.OF
# i:3,code:005827.OF
# i:4,code:007119.OF
# i:5,code:110011.OF
# i:6,code:161005.SZ
# i:7,code:000800.OF
# i:8,code:519736.OF
# i:9,code:163402.SZ
# i:10,code:003095.OF
# i:11,code:163406.SZ
# i:12,code:002190.OF
# i:13,code:164908.OF
# i:14,code:000772.OF
#          基金名称       基金代码 基金经理 性别      上任日期     基金公司  管理费   托管费      成立时间  \
# 0     睿远成长价值A  007119.OF  傅鹏博  M  20190326     睿远基金  1.5  0.15  20190326
# 1     中欧时代先锋A  001938.OF  刘伟伟  M  20211217     中欧基金  1.5  0.25  20151103
# 2     景顺鼎益LOF  162605.SZ  刘彦春  M  20150710   景顺长城基金  1.5  0.25  20050316
# 3     广发双擎升级A  005911.OF  刘格菘  M  20181102     广发基金  1.5  0.25  20181102
# 4     易方达蓝筹精选  005827.OF   张坤  M  20180905    易方达基金  1.5  0.25  20180905
# 5     易方达优质精选  110011.OF   张坤  M  20210910    易方达基金  1.5  0.25  20210910
# 6     富国天惠LOF  161005.SZ  朱少醒  M  20051116     富国基金  1.5  0.25  20051116
# 7      华商未来主题  000800.OF  李双全  M  20190823     华商基金  1.5  0.25  20141014
# 8       交银新成长  519736.OF   王崇  M  20141022  交银施罗德基金  1.5  0.25  20140509
# 9     兴全趋势LOF  163402.SZ   童兰  F  20200702   兴证全球基金  1.5  0.25  20051103
# 10    中欧医疗健康A  003095.OF   葛兰  F  20160929     中欧基金  1.5  0.25  20160929
# 11    兴全合润LOF  163406.SZ  谢治宇  M  20130129   兴证全球基金  1.5  0.25  20100422
# 12  农银汇理新能源主题  002190.OF   赵诣  M  20190820   农银汇理基金  1.5  0.25  20160329
# 13  交银中证环境治理A  164908.OF  邵文婷  F  20210430  交银施罗德基金  1.0  0.20  20160719
# 14   景顺长城中国回报  000772.OF  韩文强  M  20191010   景顺长城基金  1.5  0.25  20141106
#
#       基金规模(亿元)    规模对应日期      2018      2019      2020      2021      2022
# 0   326.890380  20211231       NaN  0.207500  0.709979  0.026104 -0.315099
# 1   190.994106  20210930 -0.083308  0.442859  0.375462  0.072199 -0.177790
# 2   226.506554  20210930 -0.053947  0.195658  0.362284 -0.052353 -0.097272
# 3   141.091313  20210930 -0.017000  1.216887  0.643585  0.042466 -0.274600
# 4   698.473170  20210930 -0.052900  0.551156  0.950922 -0.098950 -0.195160
# 5   216.617010  20210930 -0.129849  0.585684  0.715145 -0.108154 -0.160545
# 6   367.843794  20210930 -0.113196  0.215553  0.256741  0.002546 -0.126853
# 7     5.101099  20210930 -0.373640  0.403475  0.221458  0.159910 -0.235922
# 8   129.690903  20210930 -0.133661  0.471841  0.487781  0.033499 -0.224383
# 9   333.099237  20210930 -0.064737  0.110949  0.140646  0.012392 -0.075863
# 10  312.688880  20210930 -0.141935  0.699248  0.947456 -0.057086 -0.208735
# 11  287.562912  20210930 -0.255350  0.628653  0.751603  0.063242 -0.279421
# 12  259.182529  20210930 -0.344068  0.346350  1.634861  0.561994 -0.269098
# 13    3.088103  20210930 -0.454846  0.030303 -0.037255  0.199593 -0.215620
# 14   14.716587  20210930 -0.271923  0.388664  0.435860  0.006091 -0.011100

# %%
def color_returns(val):
    if val >=0:
        color = '#EE7621' # light red 
    elif val <0:
        color = '#99ff66' # light green 
    else:
        color = '#FFFAFA' # ligth gray 
    return f'background-color: {color}'

format_dict = {'基金规模(亿元)': '￥{0:.1f}', 
               '管理费': '{0:.1f}', 
               '托管费': '{0:.2f}', 
               2017: '{0:.1%}', 
               2018: '{0:.1%}', 
               2019: '{0:.1%}', 
               2020: '{0:.1%}', 
               2021: '{0:.1%}', 
               2022: '{0:.1%}', 
                }


df.style.hide(axis='index')\
                    .hide(['规模对应日期','成立时间'],axis='columns')\
                    .format(format_dict)\
                    .applymap(color_returns,subset=year_list)\
                    .background_gradient(subset=['基金规模(亿元)'],cmap='Blues')
# Out:
# <style type="text/css">
# #T_83e52_row0_col9 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_83e52_row0_col11 {
#   background-color: #FFFAFA;
# }
# #T_83e52_row0_col12, #T_83e52_row0_col13, #T_83e52_row0_col14, #T_83e52_row1_col12, #T_83e52_row1_col13, #T_83e52_row1_col14, #T_83e52_row2_col12, #T_83e52_row2_col13, #T_83e52_row3_col12, #T_83e52_row3_col13, #T_83e52_row3_col14, #T_83e52_row4_col12, #T_83e52_row4_col13, #T_83e52_row5_col12, #T_83e52_row5_col13, #T_83e52_row6_col12, #T_83e52_row6_col13, #T_83e52_row6_col14, #T_83e52_row7_col12, #T_83e52_row7_col13, #T_83e52_row7_col14, #T_83e52_row8_col12, #T_83e52_row8_col13, #T_83e52_row8_col14, #T_83e52_row9_col12, #T_83e52_row9_col13, #T_83e52_row9_col14, #T_83e52_row10_col12, #T_83e52_row10_col13, #T_83e52_row11_col12, #T_83e52_row11_col13, #T_83e52_row11_col14, #T_83e52_row12_col12, #T_83e52_row12_col13, #T_83e52_row12_col14, #T_83e52_row13_col12, #T_83e52_row13_col14, #T_83e52_row14_col12, #T_83e52_row14_col13, #T_83e52_row14_col14 {
#   background-color: #EE7621;
# }
# #T_83e52_row0_col15, #T_83e52_row1_col11, #T_83e52_row1_col15, #T_83e52_row2_col11, #T_83e52_row2_col14, #T_83e52_row2_col15, #T_83e52_row3_col11, #T_83e52_row3_col15, #T_83e52_row4_col11, #T_83e52_row4_col14, #T_83e52_row4_col15, #T_83e52_row5_col11, #T_83e52_row5_col14, #T_83e52_row5_col15, #T_83e52_row6_col11, #T_83e52_row6_col15, #T_83e52_row7_col11, #T_83e52_row7_col15, #T_83e52_row8_col11, #T_83e52_row8_col15, #T_83e52_row9_col11, #T_83e52_row9_col15, #T_83e52_row10_col11, #T_83e52_row10_col14, #T_83e52_row10_col15, #T_83e52_row11_col11, #T_83e52_row11_col15, #T_83e52_row12_col11, #T_83e52_row12_col15, #T_83e52_row13_col11, #T_83e52_row13_col13, #T_83e52_row13_col15, #T_83e52_row14_col11, #T_83e52_row14_col15 {
#   background-color: #99ff66;
# }
# #T_83e52_row1_col9 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_83e52_row2_col9 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_83e52_row3_col9 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_83e52_row4_col9 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_83e52_row5_col9 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_83e52_row6_col9 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_83e52_row7_col9, #T_83e52_row13_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_83e52_row8_col9 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_83e52_row9_col9 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_83e52_row10_col9 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_83e52_row11_col9 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_83e52_row12_col9 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_83e52_row14_col9 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# </style>
# <table id="T_83e52">
#   <thead>
#     <tr>
#       <th id="T_83e52_level0_col0" class="col_heading level0 col0" >基金名称</th>
#       <th id="T_83e52_level0_col1" class="col_heading level0 col1" >基金代码</th>
#       <th id="T_83e52_level0_col2" class="col_heading level0 col2" >基金经理</th>
#       <th id="T_83e52_level0_col3" class="col_heading level0 col3" >性别</th>
#       <th id="T_83e52_level0_col4" class="col_heading level0 col4" >上任日期</th>
#       <th id="T_83e52_level0_col5" class="col_heading level0 col5" >基金公司</th>
#       <th id="T_83e52_level0_col6" class="col_heading level0 col6" >管理费</th>
#       <th id="T_83e52_level0_col7" class="col_heading level0 col7" >托管费</th>
#       <th id="T_83e52_level0_col9" class="col_heading level0 col9" >基金规模(亿元)</th>
#       <th id="T_83e52_level0_col11" class="col_heading level0 col11" >2018</th>
#       <th id="T_83e52_level0_col12" class="col_heading level0 col12" >2019</th>
#       <th id="T_83e52_level0_col13" class="col_heading level0 col13" >2020</th>
#       <th id="T_83e52_level0_col14" class="col_heading level0 col14" >2021</th>
#       <th id="T_83e52_level0_col15" class="col_heading level0 col15" >2022</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_83e52_row0_col0" class="data row0 col0" >睿远成长价值A</td>
#       <td id="T_83e52_row0_col1" class="data row0 col1" >007119.OF</td>
#       <td id="T_83e52_row0_col2" class="data row0 col2" >傅鹏博</td>
#       <td id="T_83e52_row0_col3" class="data row0 col3" >M</td>
#       <td id="T_83e52_row0_col4" class="data row0 col4" >20190326</td>
#       <td id="T_83e52_row0_col5" class="data row0 col5" >睿远基金</td>
#       <td id="T_83e52_row0_col6" class="data row0 col6" >1.5</td>
#       <td id="T_83e52_row0_col7" class="data row0 col7" >0.15</td>
#       <td id="T_83e52_row0_col9" class="data row0 col9" >￥326.9</td>
#       <td id="T_83e52_row0_col11" class="data row0 col11" >nan%</td>
#       <td id="T_83e52_row0_col12" class="data row0 col12" >20.8%</td>
#       <td id="T_83e52_row0_col13" class="data row0 col13" >71.0%</td>
#       <td id="T_83e52_row0_col14" class="data row0 col14" >2.6%</td>
#       <td id="T_83e52_row0_col15" class="data row0 col15" >-31.5%</td>
#     </tr>
#     <tr>
#       <td id="T_83e52_row1_col0" class="data row1 col0" >中欧时代先锋A</td>
#       <td id="T_83e52_row1_col1" class="data row1 col1" >001938.OF</td>
#       <td id="T_83e52_row1_col2" class="data row1 col2" >刘伟伟</td>
#       <td id="T_83e52_row1_col3" class="data row1 col3" >M</td>
#       <td id="T_83e52_row1_col4" class="data row1 col4" >20211217</td>
#       <td id="T_83e52_row1_col5" class="data row1 col5" >中欧基金</td>
#       <td id="T_83e52_row1_col6" class="data row1 col6" >1.5</td>
#       <td id="T_83e52_row1_col7" class="data row1 col7" >0.25</td>
#       <td id="T_83e52_row1_col9" class="data row1 col9" >￥191.0</td>
#       <td id="T_83e52_row1_col11" class="data row1 col11" >-8.3%</td>
#       <td id="T_83e52_row1_col12" class="data row1 col12" >44.3%</td>
#       <td id="T_83e52_row1_col13" class="data row1 col13" >37.5%</td>
#       <td id="T_83e52_row1_col14" class="data row1 col14" >7.2%</td>
#       <td id="T_83e52_row1_col15" class="data row1 col15" >-17.8%</td>
#     </tr>
#     <tr>
#       <td id="T_83e52_row2_col0" class="data row2 col0" >景顺鼎益LOF</td>
#       <td id="T_83e52_row2_col1" class="data row2 col1" >162605.SZ</td>
#       <td id="T_83e52_row2_col2" class="data row2 col2" >刘彦春</td>
#       <td id="T_83e52_row2_col3" class="data row2 col3" >M</td>
#       <td id="T_83e52_row2_col4" class="data row2 col4" >20150710</td>
#       <td id="T_83e52_row2_col5" class="data row2 col5" >景顺长城基金</td>
#       <td id="T_83e52_row2_col6" class="data row2 col6" >1.5</td>
#       <td id="T_83e52_row2_col7" class="data row2 col7" >0.25</td>
#       <td id="T_83e52_row2_col9" class="data row2 col9" >￥226.5</td>
#       <td id="T_83e52_row2_col11" class="data row2 col11" >-5.4%</td>
#       <td id="T_83e52_row2_col12" class="data row2 col12" >19.6%</td>
#       <td id="T_83e52_row2_col13" class="data row2 col13" >36.2%</td>
#       <td id="T_83e52_row2_col14" class="data row2 col14" >-5.2%</td>
#       <td id="T_83e52_row2_col15" class="data row2 col15" >-9.7%</td>
#     </tr>
#     <tr>
#       <td id="T_83e52_row3_col0" class="data row3 col0" >广发双擎升级A</td>
#       <td id="T_83e52_row3_col1" class="data row3 col1" >005911.OF</td>
#       <td id="T_83e52_row3_col2" class="data row3 col2" >刘格菘</td>
#       <td id="T_83e52_row3_col3" class="data row3 col3" >M</td>
#       <td id="T_83e52_row3_col4" class="data row3 col4" >20181102</td>
#       <td id="T_83e52_row3_col5" class="data row3 col5" >广发基金</td>
#       <td id="T_83e52_row3_col6" class="data row3 col6" >1.5</td>
#       <td id="T_83e52_row3_col7" class="data row3 col7" >0.25</td>
#       <td id="T_83e52_row3_col9" class="data row3 col9" >￥141.1</td>
#       <td id="T_83e52_row3_col11" class="data row3 col11" >-1.7%</td>
#       <td id="T_83e52_row3_col12" class="data row3 col12" >121.7%</td>
#       <td id="T_83e52_row3_col13" class="data row3 col13" >64.4%</td>
#       <td id="T_83e52_row3_col14" class="data row3 col14" >4.2%</td>
#       <td id="T_83e52_row3_col15" class="data row3 col15" >-27.5%</td>
#     </tr>
#     <tr>
#       <td id="T_83e52_row4_col0" class="data row4 col0" >易方达蓝筹精选</td>
#       <td id="T_83e52_row4_col1" class="data row4 col1" >005827.OF</td>
#       <td id="T_

# %%
df.style.hide(axis='index')\
                    .hide(['规模对应日期','成立时间',2018,2019,2020,2021,2022],axis='columns')\
                    .format(format_dict)\
                    .applymap(color_returns,subset=year_list)\
                    .background_gradient(subset=['基金规模(亿元)'],cmap='Blues')
# Out:
# <style type="text/css">
# #T_a497b_row0_col9 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_a497b_row1_col9 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_a497b_row2_col9 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_a497b_row3_col9 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_a497b_row4_col9 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_a497b_row5_col9 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_a497b_row6_col9 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_a497b_row7_col9, #T_a497b_row13_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_a497b_row8_col9 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_a497b_row9_col9 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_a497b_row10_col9 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_a497b_row11_col9 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_a497b_row12_col9 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_a497b_row14_col9 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# </style>
# <table id="T_a497b">
#   <thead>
#     <tr>
#       <th id="T_a497b_level0_col0" class="col_heading level0 col0" >基金名称</th>
#       <th id="T_a497b_level0_col1" class="col_heading level0 col1" >基金代码</th>
#       <th id="T_a497b_level0_col2" class="col_heading level0 col2" >基金经理</th>
#       <th id="T_a497b_level0_col3" class="col_heading level0 col3" >性别</th>
#       <th id="T_a497b_level0_col4" class="col_heading level0 col4" >上任日期</th>
#       <th id="T_a497b_level0_col5" class="col_heading level0 col5" >基金公司</th>
#       <th id="T_a497b_level0_col6" class="col_heading level0 col6" >管理费</th>
#       <th id="T_a497b_level0_col7" class="col_heading level0 col7" >托管费</th>
#       <th id="T_a497b_level0_col9" class="col_heading level0 col9" >基金规模(亿元)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a497b_row0_col0" class="data row0 col0" >睿远成长价值A</td>
#       <td id="T_a497b_row0_col1" class="data row0 col1" >007119.OF</td>
#       <td id="T_a497b_row0_col2" class="data row0 col2" >傅鹏博</td>
#       <td id="T_a497b_row0_col3" class="data row0 col3" >M</td>
#       <td id="T_a497b_row0_col4" class="data row0 col4" >20190326</td>
#       <td id="T_a497b_row0_col5" class="data row0 col5" >睿远基金</td>
#       <td id="T_a497b_row0_col6" class="data row0 col6" >1.5</td>
#       <td id="T_a497b_row0_col7" class="data row0 col7" >0.15</td>
#       <td id="T_a497b_row0_col9" class="data row0 col9" >￥326.9</td>
#     </tr>
#     <tr>
#       <td id="T_a497b_row1_col0" class="data row1 col0" >中欧时代先锋A</td>
#       <td id="T_a497b_row1_col1" class="data row1 col1" >001938.OF</td>
#       <td id="T_a497b_row1_col2" class="data row1 col2" >刘伟伟</td>
#       <td id="T_a497b_row1_col3" class="data row1 col3" >M</td>
#       <td id="T_a497b_row1_col4" class="data row1 col4" >20211217</td>
#       <td id="T_a497b_row1_col5" class="data row1 col5" >中欧基金</td>
#       <td id="T_a497b_row1_col6" class="data row1 col6" >1.5</td>
#       <td id="T_a497b_row1_col7" class="data row1 col7" >0.25</td>
#       <td id="T_a497b_row1_col9" class="data row1 col9" >￥191.0</td>
#     </tr>
#     <tr>
#       <td id="T_a497b_row2_col0" class="data row2 col0" >景顺鼎益LOF</td>
#       <td id="T_a497b_row2_col1" class="data row2 col1" >162605.SZ</td>
#       <td id="T_a497b_row2_col2" class="data row2 col2" >刘彦春</td>
#       <td id="T_a497b_row2_col3" class="data row2 col3" >M</td>
#       <td id="T_a497b_row2_col4" class="data row2 col4" >20150710</td>
#       <td id="T_a497b_row2_col5" class="data row2 col5" >景顺长城基金</td>
#       <td id="T_a497b_row2_col6" class="data row2 col6" >1.5</td>
#       <td id="T_a497b_row2_col7" class="data row2 col7" >0.25</td>
#       <td id="T_a497b_row2_col9" class="data row2 col9" >￥226.5</td>
#     </tr>
#     <tr>
#       <td id="T_a497b_row3_col0" class="data row3 col0" >广发双擎升级A</td>
#       <td id="T_a497b_row3_col1" class="data row3 col1" >005911.OF</td>
#       <td id="T_a497b_row3_col2" class="data row3 col2" >刘格菘</td>
#       <td id="T_a497b_row3_col3" class="data row3 col3" >M</td>
#       <td id="T_a497b_row3_col4" class="data row3 col4" >20181102</td>
#       <td id="T_a497b_row3_col5" class="data row3 col5" >广发基金</td>
#       <td id="T_a497b_row3_col6" class="data row3 col6" >1.5</td>
#       <td id="T_a497b_row3_col7" class="data row3 col7" >0.25</td>
#       <td id="T_a497b_row3_col9" class="data row3 col9" >￥141.1</td>
#     </tr>
#     <tr>
#       <td id="T_a497b_row4_col0" class="data row4 col0" >易方达蓝筹精选</td>
#       <td id="T_a497b_row4_col1" class="data row4 col1" >005827.OF</td>
#       <td id="T_a497b_row4_col2" class="data row4 col2" >张坤</td>
#       <td id="T_a497b_row4_col3" class="data row4 col3" >M</td>
#       <td id="T_a497b_row4_col4" class="data row4 col4" >20180905</td>
#       <td id="T_a497b_row4_col5" class="data row4 col5" >易方达基金</td>
#       <td id="T_a497b_row4_col6" class="data row4 col6" >1.5</td>
#       <td id="T_a497b_row4_col7" class="data row4 col7" >0.25</td>
#       <td id="T_a497b_row4_col9" class="data row4 col9" >￥698.5</td>
#     </tr>
#     <tr>
#       <td id="T_a497b_row5_col0" class="data row5 col0" >易方达优质精选</td>
#       <td id="T_a497b_row5_col1" class="data row5 col1" >110011.OF</td>
#       <td id="T_a497b_row5_col2" class="data row5 col2" >张坤</td>
#       <td id="T_a497b_row5_col3" class="data row5 col3" >M</td>
#       <td id="T_a497b_row5_col4" class="data row5 col4" >20210910</td>
#       <td id="T_a497b_row5_col5" class="data row5 col5" >易方达基金</td>
#       <td id="T_a497b_row5_col6" class="data row5 col6" >1.5</td>
#       <td id="T_a497b_row5_col7" class="data row5 col7" >0.25</td>
#       <td id="T_a497b_row5_col9" class="data row5 col9" >￥216.6</td>
#     </tr>
#     <tr>
#       <td id="T_a497b_row6_col0" class="data row6 col0" >富国天惠LOF</td>
#       <td id="T_a497b_row6_col1" class="data row6 col1" >161005.SZ</td>
#       <td id="T_a497b_row6_col2" class="data row6 col2" >朱少醒</td>
#       <td id="T_a497b_row6_col3" class="data row6 col3" >M</td>
#       <td id="T_a497b_row6_col4" class="data row6 col4" >20051116</td>
#       <td id="T_a497b_row6_col5" class="data row6 col5" >富国基金</td>
#       <td id="T_a497b_row6_col6" class="data row6 col6" >1.5</td>
#       <td id="T_a497b_row6_col7" class="data row6 col7" >0.25</td>
#       <td id="T_a497b_row6_col9" class="data row6 col9" >￥367.8</td>
#     </tr>
#     <tr>
#       <td id="T_a497b_row7_col0" class="data row7 col0" >华商未来主题</td>
#       <td id="T_a497b_row7_col1" class="data row7 col1" >000800.OF</td>
#       <td id="T_a497b_row7_col2" class="data row7 col2" >李双全</td>
#       <td id="T_a497b_row7_col3" class="data row7 col3" >M</td>
#       <td id="T_a497b_row7_col4" class="data row7 col4" >20190823</td>
#       <td id="T_a497b_row7_col5" class="data row7 col5" >华商基金</td>
#       <td id="T_a497b_row7_col6" class="data row7 col6" >1.5</td>
#       <td id="T_a497b_row7_col7" class="data row7 col7" >0.25</td>
#       <td id="T_a497b_row7_col9" class="data row7 col9" >￥5.1</td>
#     </tr>
#     <tr>
#       <td id="T_a497b_row8_col0" class="data row8 col0" >交银新成长</td>
#       <td id="T_a497b_row8_col1" class="data row8 col1" >519736.OF</td>
#       <td id="T_a497b_row8_col2" class="data row8 col2" >王崇</td>
#       <td id="T_a497b_row8_col3" class="data row8 col3" >M</td>
#       <td id="T_a497b_row8_col4" class="data row8 col4" >20141022</td>
#       <td id="T_a497b_row8_col5" class="data row8 col5" >交银施罗德基金</td>
#       <td id="T_a497b_row8_col6" class="data row8 col6" >1.5</td>
#       <td id="T_a497b_row8_col7" class="data row8 col7" >0.25</td>
#       <td id="T_a497b_row8_col9" class="data row8 col9" >￥129.7</td>
#     </tr>
#     <tr>
#       <td id="T_a497b_row9_col0" class="data row9 col0" >兴全趋势LOF</td>
#       <td id="T_a497b_row9_col1" class="data row9 col1" >163402.SZ</td>
#       <td id="T_a497b_row9_col2" class="data row9 col2" >童兰</td>
#       <td id="T_a497b_row9_col3" class="data row9 col3" >F</td>
#       <td id="T_a497b_row9_col4" class="data row9 col4" >20200702</td>
#       <td id="T_a497b_row9_col5" class="data row9 col5" >兴证全球基金</td>
#       <td id="T_a497b_row9_col6" class="data row9 col6" >1.5</td>
#       <td id="T_a497b_row

# %%
df.style.hide(axis='index')\
                    .hide(['规模对应日期','成立时间','基金代码','性别','上任日期','基金公司','管理费','托管费','基金规模(亿元)'],axis='columns')\
                    .format(format_dict)\
                    .applymap(color_returns,subset=year_list)
# Out:
# <style type="text/css">
# #T_9cc73_row0_col11 {
#   background-color: #FFFAFA;
# }
# #T_9cc73_row0_col12, #T_9cc73_row0_col13, #T_9cc73_row0_col14, #T_9cc73_row1_col12, #T_9cc73_row1_col13, #T_9cc73_row1_col14, #T_9cc73_row2_col12, #T_9cc73_row2_col13, #T_9cc73_row3_col12, #T_9cc73_row3_col13, #T_9cc73_row3_col14, #T_9cc73_row4_col12, #T_9cc73_row4_col13, #T_9cc73_row5_col12, #T_9cc73_row5_col13, #T_9cc73_row6_col12, #T_9cc73_row6_col13, #T_9cc73_row6_col14, #T_9cc73_row7_col12, #T_9cc73_row7_col13, #T_9cc73_row7_col14, #T_9cc73_row8_col12, #T_9cc73_row8_col13, #T_9cc73_row8_col14, #T_9cc73_row9_col12, #T_9cc73_row9_col13, #T_9cc73_row9_col14, #T_9cc73_row10_col12, #T_9cc73_row10_col13, #T_9cc73_row11_col12, #T_9cc73_row11_col13, #T_9cc73_row11_col14, #T_9cc73_row12_col12, #T_9cc73_row12_col13, #T_9cc73_row12_col14, #T_9cc73_row13_col12, #T_9cc73_row13_col14, #T_9cc73_row14_col12, #T_9cc73_row14_col13, #T_9cc73_row14_col14 {
#   background-color: #EE7621;
# }
# #T_9cc73_row0_col15, #T_9cc73_row1_col11, #T_9cc73_row1_col15, #T_9cc73_row2_col11, #T_9cc73_row2_col14, #T_9cc73_row2_col15, #T_9cc73_row3_col11, #T_9cc73_row3_col15, #T_9cc73_row4_col11, #T_9cc73_row4_col14, #T_9cc73_row4_col15, #T_9cc73_row5_col11, #T_9cc73_row5_col14, #T_9cc73_row5_col15, #T_9cc73_row6_col11, #T_9cc73_row6_col15, #T_9cc73_row7_col11, #T_9cc73_row7_col15, #T_9cc73_row8_col11, #T_9cc73_row8_col15, #T_9cc73_row9_col11, #T_9cc73_row9_col15, #T_9cc73_row10_col11, #T_9cc73_row10_col14, #T_9cc73_row10_col15, #T_9cc73_row11_col11, #T_9cc73_row11_col15, #T_9cc73_row12_col11, #T_9cc73_row12_col15, #T_9cc73_row13_col11, #T_9cc73_row13_col13, #T_9cc73_row13_col15, #T_9cc73_row14_col11, #T_9cc73_row14_col15 {
#   background-color: #99ff66;
# }
# </style>
# <table id="T_9cc73">
#   <thead>
#     <tr>
#       <th id="T_9cc73_level0_col0" class="col_heading level0 col0" >基金名称</th>
#       <th id="T_9cc73_level0_col2" class="col_heading level0 col2" >基金经理</th>
#       <th id="T_9cc73_level0_col11" class="col_heading level0 col11" >2018</th>
#       <th id="T_9cc73_level0_col12" class="col_heading level0 col12" >2019</th>
#       <th id="T_9cc73_level0_col13" class="col_heading level0 col13" >2020</th>
#       <th id="T_9cc73_level0_col14" class="col_heading level0 col14" >2021</th>
#       <th id="T_9cc73_level0_col15" class="col_heading level0 col15" >2022</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9cc73_row0_col0" class="data row0 col0" >睿远成长价值A</td>
#       <td id="T_9cc73_row0_col2" class="data row0 col2" >傅鹏博</td>
#       <td id="T_9cc73_row0_col11" class="data row0 col11" >nan%</td>
#       <td id="T_9cc73_row0_col12" class="data row0 col12" >20.8%</td>
#       <td id="T_9cc73_row0_col13" class="data row0 col13" >71.0%</td>
#       <td id="T_9cc73_row0_col14" class="data row0 col14" >2.6%</td>
#       <td id="T_9cc73_row0_col15" class="data row0 col15" >-31.5%</td>
#     </tr>
#     <tr>
#       <td id="T_9cc73_row1_col0" class="data row1 col0" >中欧时代先锋A</td>
#       <td id="T_9cc73_row1_col2" class="data row1 col2" >刘伟伟</td>
#       <td id="T_9cc73_row1_col11" class="data row1 col11" >-8.3%</td>
#       <td id="T_9cc73_row1_col12" class="data row1 col12" >44.3%</td>
#       <td id="T_9cc73_row1_col13" class="data row1 col13" >37.5%</td>
#       <td id="T_9cc73_row1_col14" class="data row1 col14" >7.2%</td>
#       <td id="T_9cc73_row1_col15" class="data row1 col15" >-17.8%</td>
#     </tr>
#     <tr>
#       <td id="T_9cc73_row2_col0" class="data row2 col0" >景顺鼎益LOF</td>
#       <td id="T_9cc73_row2_col2" class="data row2 col2" >刘彦春</td>
#       <td id="T_9cc73_row2_col11" class="data row2 col11" >-5.4%</td>
#       <td id="T_9cc73_row2_col12" class="data row2 col12" >19.6%</td>
#       <td id="T_9cc73_row2_col13" class="data row2 col13" >36.2%</td>
#       <td id="T_9cc73_row2_col14" class="data row2 col14" >-5.2%</td>
#       <td id="T_9cc73_row2_col15" class="data row2 col15" >-9.7%</td>
#     </tr>
#     <tr>
#       <td id="T_9cc73_row3_col0" class="data row3 col0" >广发双擎升级A</td>
#       <td id="T_9cc73_row3_col2" class="data row3 col2" >刘格菘</td>
#       <td id="T_9cc73_row3_col11" class="data row3 col11" >-1.7%</td>
#       <td id="T_9cc73_row3_col12" class="data row3 col12" >121.7%</td>
#       <td id="T_9cc73_row3_col13" class="data row3 col13" >64.4%</td>
#       <td id="T_9cc73_row3_col14" class="data row3 col14" >4.2%</td>
#       <td id="T_9cc73_row3_col15" class="data row3 col15" >-27.5%</td>
#     </tr>
#     <tr>
#       <td id="T_9cc73_row4_col0" class="data row4 col0" >易方达蓝筹精选</td>
#       <td id="T_9cc73_row4_col2" class="data row4 col2" >张坤</td>
#       <td id="T_9cc73_row4_col11" class="data row4 col11" >-5.3%</td>
#       <td id="T_9cc73_row4_col12" class="data row4 col12" >55.1%</td>
#       <td id="T_9cc73_row4_col13" class="data row4 col13" >95.1%</td>
#       <td id="T_9cc73_row4_col14" class="data row4 col14" >-9.9%</td>
#       <td id="T_9cc73_row4_col15" class="data row4 col15" >-19.5%</td>
#     </tr>
#     <tr>
#       <td id="T_9cc73_row5_col0" class="data row5 col0" >易方达优质精选</td>
#       <td id="T_9cc73_row5_col2" class="data row5 col2" >张坤</td>
#       <td id="T_9cc73_row5_col11" class="data row5 col11" >-13.0%</td>
#       <td id="T_9cc73_row5_col12" class="data row5 col12" >58.6%</td>
#       <td id="T_9cc73_row5_col13" class="data row5 col13" >71.5%</td>
#       <td id="T_9cc73_row5_col14" class="data row5 col14" >-10.8%</td>
#       <td id="T_9cc73_row5_col15" class="data row5 col15" >-16.1%</td>
#     </tr>
#     <tr>
#       <td id="T_9cc73_row6_col0" class="data row6 col0" >富国天惠LOF</td>
#       <td id="T_9cc73_row6_col2" class="data row6 col2" >朱少醒</td>
#       <td id="T_9cc73_row6_col11" class="data row6 col11" >-11.3%</td>
#       <td id="T_9cc73_row6_col12" class="data row6 col12" >21.6%</td>
#       <td id="T_9cc73_row6_col13" class="data row6 col13" >25.7%</td>
#       <td id="T_9cc73_row6_col14" class="data row6 col14" >0.3%</td>
#       <td id="T_9cc73_row6_col15" class="data row6 col15" >-12.7%</td>
#     </tr>
#     <tr>
#       <td id="T_9cc73_row7_col0" class="data row7 col0" >华商未来主题</td>
#       <td id="T_9cc73_row7_col2" class="data row7 col2" >李双全</td>
#       <td id="T_9cc73_row7_col11" class="data row7 col11" >-37.4%</td>
#       <td id="T_9cc73_row7_col12" class="data row7 col12" >40.3%</td>
#       <td id="T_9cc73_row7_col13" class="data row7 col13" >22.1%</td>
#       <td id="T_9cc73_row7_col14" class="data row7 col14" >16.0%</td>
#       <td id="T_9cc73_row7_col15" class="data row7 col15" >-23.6%</td>
#     </tr>
#     <tr>
#       <td id="T_9cc73_row8_col0" class="data row8 col0" >交银新成长</td>
#       <td id="T_9cc73_row8_col2" class="data row8 col2" >王崇</td>
#       <td id="T_9cc73_row8_col11" class="data row8 col11" >-13.4%</td>
#       <td id="T_9cc73_row8_col12" class="data row8 col12" >47.2%</td>
#       <td id="T_9cc73_row8_col13" class="data row8 col13" >48.8%</td>
#       <td id="T_9cc73_row8_col14" class="data row8 col14" >3.3%</td>
#       <td id="T_9cc73_row8_col15" class="data row8 col15" >-22.4%</td>
#     </tr>
#     <tr>
#       <td id="T_9cc73_row9_col0" class="data row9 col0" >兴全趋势LOF</td>
#       <td id="T_9cc73_row9_col2" class="data row9 col2" >童兰</td>
#       <td id="T_9cc73_row9_col11" class="data row9 col11" >-6.5%</td>
#       <td id="T_9cc73_row9_col12" class="data row9 col12" >11.1%</td>
#       <td id="T_9cc73_row9_col13" class="data row9 col13" >14.1%</td>
#       <td id="T_9cc73_row9_col14" class="data row9 col14" >1.2%</td>
#       <td id="T_9cc73_row9_col15" class="data row9 col15" >-7.6%</td>
#     </tr>
#     <tr>
#       <td id="T_9cc73_row10_col0" class="data row10 col0" >中欧医疗健康A</td>
#       <td id="T_9cc73_row10_col2" class="data row10 col2" >葛兰</td>
#       <td id="T_9cc73_row10_col11" class="data row10 col11" >-14.2%</td>
#       <td id="T_9cc73_row10_col12" class="data row10 col12" >69.9%</td>
#       <td id="T_9cc73_row10_col13" class="data row10 col13" >94.7%</td>
#       <td id="T_9cc73_row10_col14" class="data row10 col14" >-5.7%</td>
#       <td id="T_9cc73_row10_col15" class="data row10 col15" >-20.9%</td>
#     </tr>
#     <tr>
#       <td id="T_9cc73_row11_col0" class="data row11 col0" >兴全合润LO

# %% [markdown]
# ## 相关阅读
#
# - [视频：Plotly 和 Dash 在投资领域的应用](https://mp.weixin.qq.com/s/VopPrpe_64j5za4AYkmUTg)
#
# - [视频：Plotly中绘制股票交易图表](https://mp.weixin.qq.com/s/1TUB2G-xavNm796uXUnRfQ)
#
# - [Plotly中绘制三种经典的股票交易图表](https://mp.weixin.qq.com/s/1v3h5-5fNVk7cBdaRKzJkg)
#
# - [神器Tushare，财经数据必备工具！](https://mp.weixin.qq.com/s/c1ukemeK12flCgA-lo69fA)
#
# - [股票亏惨了，用Python来做一个投资计划](https://mp.weixin.qq.com/s/WYuMwCJBrWaBiDs8xp2KMA)
#
# - [用 Python 读取巴菲特近期持仓数据](https://mp.weixin.qq.com/s/6h9Xq2lfrZSlRNw_W8aWcg)
#
# 更多内容，请关注公众号「**Python数据之道**」：
#
# [![](https://tva1.sinaimg.cn/large/e6c9d24egy1h0iiejjflzj20go05kdhg.jpg)](https://mp.weixin.qq.com/mp/appmsgalbum?__biz=MzI2NjY5NzI0NA==&action=getalbum&album_id=2293754972943122444#wechat_redirect)
#
#
# [![](https://tva1.sinaimg.cn/large/e6c9d24egy1h0iieh8vk4j20go05kaag.jpg)](https://mp.weixin.qq.com/mp/appmsgalbum?__biz=MzI2NjY5NzI0NA==&action=getalbum&album_id=1370549534602133504&scene=21#wechat_redirect)
#
#
# ![](https://tva1.sinaimg.cn/large/008i3skNgy1gs2d9ca7dvj31hc0u07ng.jpg)
