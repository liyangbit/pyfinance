# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#获取基金费率等信息" data-toc-modified-id="获取基金费率等信息-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>获取基金费率等信息</a></span></li><li><span><a href="#获取基金经理信息" data-toc-modified-id="获取基金经理信息-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>获取基金经理信息</a></span></li><li><span><a href="#获取基金规模，年度收益信息" data-toc-modified-id="获取基金规模，年度收益信息-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>获取基金规模，年度收益信息</a></span></li><li><span><a href="#获取多只基金的信息" data-toc-modified-id="获取多只基金的信息-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>获取多只基金的信息</a></span></li><li><span><a href="#相关阅读" data-toc-modified-id="相关阅读-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>相关阅读</a></span></li></ul></div>

# %%
import pandas as pd
import datetime
import numpy as np
import tushare as ts

# %% [markdown]
# 使用tushare 获取财经数据，首先需要注册，注册地址如下：
#
# [点击注册tushare](https://tushare.pro/register?reg=129033)
#
# 然后按照下面的代码设置 token
#
# 以上方法只需要在第一次或者token失效后调用，完成调取tushare数据凭证的设置，正常情况下不需要重复设置。

# %%
# token='XXXXXXX'  
# ts.set_token(token)

pro = ts.pro_api()

# %% [markdown]
# ## 获取基金费率等信息

# %%
# 获取基金中文名称信息
df_e = pro.fund_basic(market='E')
df_o = pro.fund_basic(market='O')
df_fund_info = df_e.append(df_o)
df_fund_info = df_fund_info[['ts_code','name', 'management','m_fee', 'c_fee','found_date']]
df_fund_info.columns = ['fund_code','fund_name', 'management','m_fee', 'c_fee','found_date']
df_fund_info = df_fund_info.reset_index(drop=True)
df_fund_info
# Out:
#        fund_code         fund_name management  m_fee  c_fee found_date
# 0      159713.SZ             稀土ETF       富国基金   0.50   0.10   20210805
# 1      561910.SH             电池ETF       招商基金   0.50   0.10   20210804
# 2      517010.SH       沪港深500ETF指数      易方达基金   0.15   0.05   20210803
# 3      159790.SZ               碳中和       华夏基金   0.50   0.10   20210730
# 4      159786.SZ             VRETF       银华基金   0.50   0.10   20210729
# ...          ...               ...        ...    ...    ...        ...
# 15862  516633.OF  华夏中证云计算与大数据主题ETF       华夏基金   0.50   0.10       None
# 15863  011481.OF          广发瑞锦一年定开       广发基金   1.00   0.10       None
# 15864  011749.OF         华泰柏瑞景气成长C     华泰柏瑞基金   1.50   0.25       None
# 15865  010721.OF             德邦安瑞C       德邦基金   0.70   0.10       None
# 15866  012668.OF         中融景泓一年持有C       中融基金   0.60   0.20       None
#
# [15867 rows x 6 columns]

# %% [markdown]
# ## 获取基金经理信息

# %%
# 获取单个基金的信息

def get_fund(fund_code,df_fund_info):    
    # 获取基金经理信息，以及开始管理该基金的日期
    df_manager = pro.fund_manager(ts_code=fund_code)
    df_manager = df_manager[df_manager['end_date'].isna()]
    df_manager = df_manager.sort_values('begin_date',ascending=True).head(1)
    begin_date = df_manager['begin_date'].values[0] # 开始管理该基金的日期
    df_manager = df_manager[['ts_code', 'name', 'gender','begin_date']]
    df_manager.columns = ['fund_code', 'manager_name', 'gender','begin_date']
    
    # 合并
    df_fund = pd.merge(df_manager,df_fund_info,how='left',on='fund_code')

    return df_fund
    
# 110011.OF,易方达中小盘

df_fund = get_fund('110011.OF',df_fund_info) 
df_fund
# Out:
#    fund_code manager_name gender begin_date fund_name management  m_fee  \
# 0  110011.OF           张坤      M   20120928    易方达中小盘      易方达基金    1.5
#
#    c_fee found_date
# 0   0.25   20080619

# %% [markdown]
# ## 获取基金规模，年度收益信息

# %%
# 获取单支基金的年度收益,基金规模等信息

def get_returns(fund_code,start_year):
    df_fund_nav = pro.fund_nav(ts_code=fund_code)
    df_fund_nav['date'] = pd.to_datetime(df_fund_nav['end_date'])
    df_fund_nav = df_fund_nav.set_index('date').sort_index()
    
    years = df_fund_nav['accum_nav'].resample('AS').sum().to_period('A')
    # 获取年度数据，类型为 pandas 的 period
    years = years.index.tolist()
    
    # 有些基金的开始日期晚于2018年，需要对齐列，补空白
    year_list = [yr.year for yr in years if yr.year>=start_year]
    
    # 将 period 时间数据转为 string 的年度数据
    years = [str(yr.year) for yr in years]

    df_yrs_index = pd.DataFrame()
    for yr in years:
        df_yr_index = df_fund_nav.loc[yr].tail(1)
        df_yrs_index = df_yrs_index.append(df_yr_index)
    df_yrs = df_fund_nav.head(1).append(df_yrs_index)

    # 计算每年的收益率，即涨跌幅度
    df_yrs['returns'] = df_yrs['accum_nav'].pct_change()

    # 删除收益率为 NA 的行 （第1天有数据记录的日期）
    df_yrs = df_yrs.dropna(subset=['returns'])

    # 筛选自开始年份以来的数据
    df_yrs = df_yrs.loc[str(start_year):]

    df_yrs = df_yrs.reset_index()
    df_yrs['year'] = df_yrs['date'].dt.year

    # 透视表
    df_yr_returns = pd.pivot_table(
        df_yrs, index=['ts_code'],
        values=['returns'], columns=['year'], fill_value=""
    )

    # 将多层索引转变为单层索引
    df_yr_returns = df_yr_returns['returns']
    df_yr_returns = df_yr_returns.reset_index()
    df_yr_returns.columns.name = None
    
    df_yr_returns = df_yr_returns.rename(columns={'ts_code':'fund_code'})
    
    # 基金份额
    df_fund_share = pro.fund_share(ts_code=fund_code).head(1)
    df_fund_share.columns = ['fund_code', 'fd_share_date', 'fd_share', 'fund_type', 'market']
    # fd_share,单位是 万份
    fd_share_date = df_fund_share['fd_share_date'].values[0] # 份额对应的日期
    
    # 份额日期的净值数据
    df_ann_nav = df_fund_nav.loc[fd_share_date:fd_share_date].sort_values('update_flag',ascending=False).head(1)
    df_ann_nav = df_ann_nav[['ts_code', 'accum_nav','unit_nav']]
    df_ann_nav.columns = ['fund_code', 'accum_nav','unit_nav']
    
    # 计算基金规模，amount，单位：亿元
    df_fund_amount = pd.merge(df_fund_share,df_ann_nav,how='left',on='fund_code')    
    df_fund_amount['amount'] = df_fund_amount['fd_share'] * df_fund_amount['unit_nav']/10000
    df_fund_amount = df_fund_amount[['fund_code','amount','fd_share_date']]
    
    # 合并数据    
    df_yr_returns = pd.merge(df_fund_amount,df_yr_returns,how='left',on='fund_code')

    for yr in year_list:
        if yr not in df_yr_returns.columns.tolist():
            df_yr_returns[yr]=np.nan
    
    return df_yr_returns

df_return = get_returns('110011.OF',2018)
df_return
# Out:
#    fund_code      amount fd_share_date      2018      2019      2020      2021
# 0  110011.OF  287.010963      20210630 -0.129849  0.585684  0.715145 -0.089598

# %% [markdown]
# ## 获取多只基金的信息

# %%
# 获取多只基金的信息

def get_data_fund(df_fund_info,fund_code_short,code_exception,start_year):
    df_filter_info = pd.DataFrame()
    for code in fund_code_short:
        df_tmp = df_fund_info[df_fund_info['fund_code'].str.contains(code)].head(1)
        df_filter_info = df_filter_info.append(df_tmp)
    df_filter_info = df_filter_info.reset_index(drop=True)   
    fund_codes = df_filter_info['fund_code'].tolist()
    # fund_codes

    df = pd.DataFrame()
    for code in fund_codes:
        if code in code_exception:
            code_update = code[:-2]+'OF'
            code_short = code[:-3]
            df_fund = get_fund(code_update,df_fund_info)
            df_fund['fund_code'] = code
            df_fund = df_fund[['fund_code','manager_name','gender','begin_date']]
            df_fund = df_fund.dropna(axis=1) # 删除含 NaN 的列
            test_m = df_fund_info[df_fund_info['fund_code'].str.contains(code_short)]
            df_fund = pd.merge(df_fund,test_m,how='left',on='fund_code')
        else:
            df_fund = get_fund(code,df_fund_info) 
        df_return = get_returns(code,start_year)
        df_fund_merge = pd.merge(df_fund,df_return,how='left',on='fund_code')
        df = df.append(df_fund_merge)
    df = df.reset_index(drop=True)
    
    df = df.rename(columns={
        'fund_code':'基金代码','manager_name':'基金经理',
        'gender':'性别','begin_date':'上任日期',
        'fund_name':'基金名称','management':'基金公司',
        'm_fee':'管理费','c_fee':'托管费',
        'found_date':'成立时间','amount':'基金规模(亿元)',
        'fd_share_date':'规模对应日期'
    })
    
    # 调整列的排序
    cols = df.columns.tolist()
    col_1 = cols[:4]
    col_2 = cols[4:5]
    col_3 = cols[5:]
    cols = col_2 + col_1 + col_3
    df = df[cols]

    return df

# %% [markdown]
# 设置具体的参数

# %%
# 需要获取的基金代码简称列表
fund_code_short = ['000772', '003095','166005','320007',
                   '163406','260101','161005','162605',
                   '163402','005827','110022','110011',
                   '164908','000800','590008',
                   '360007','118001',
                   '519736','007119','002190','005911',
                   '001938','166002','377240'
                  ]

# ['200011','690003','200010',]

# 特列：LOF 基金，基金经理和管理费等费用所用的代码两处不一致，需要调整
code_exception = ['163406.SZ','160632.SZ','160222.SZ','159843.SZ','515920.SH'] 

# 设置基金收益开始的年份
start_year = 2018
# 设置基金收益截止的年份
end_year = 2021
year_list = list(range(start_year,end_year+1))

df_fund_final = get_data_fund(df_fund_info,fund_code_short,code_exception,start_year)
df_fund_final
# Out:
#          基金名称       基金代码 基金经理 性别      上任日期     基金公司  管理费   托管费      成立时间  \
# 0    景顺长城中国回报  000772.OF  韩文强  M  20191010   景顺长城基金  1.5  0.25  20141106
# 1     中欧医疗健康A  003095.OF   葛兰  F  20160929     中欧基金  1.5  0.25  20160929
# 2     中欧价值发现A  166005.OF  曹名长  M  20151120     中欧基金  1.5  0.25  20090724
# 3        诺安成长  320007.OF  蔡嵩松  M  20190220     诺安基金  1.5  0.25  20090310
# 4        兴全合润  163406.SZ  谢治宇  M  20130129   兴证全球基金  1.5  0.25  20100422
# 5      景顺长城优选  260101.OF  杨锐文  M  20141025   景顺长城基金  1.5  0.25  20031024
# 6        富国天惠  161005.SZ  朱少醒  M  20051116     富国基金  1.5  0.25  20051116
# 7        景顺鼎益  162605.SZ  刘彦春  M  20150710   景顺长城基金  1.5  0.25  20050316
# 8        兴全趋势  163402.SZ  董承非  M  20131028   兴证全球基金  1.5  0.25  20051103
# 9     易方达蓝筹精选  005827.OF   张坤  M  20180905    易方达基金  1.5  0.25  20180905
# 10    易方达消费行业  110022.OF   萧楠  M  20120928    易方达基金  1.5  0.25  20100820
# 11     易方达中小盘  110011.OF   张坤  M  20120928    易方达基金  1.5  0.25  20080619
# 12   交银中证环境治理  164908.OF   蔡铮  M  20160719  交银施罗德基金  1.0  0.20  20160719
# 13     华商未来主题  000800.OF  李双全  M  20190823     华商基金  1.5  0.25  20141014
# 14   中邮战略新兴产业  590008.OF   杨欢  M  20180622     中邮基金  1.5  0.25  20120612
# 15       光大优势  360007.OF  戴奇雷  M  20191119  光大保德信基金  1.5  0.25  20070824
# 16    易方达亚洲精选  118001.OF   张坤  M  20140408    易方达基金  1.5  0.35  20100121
# 17      交银新成长  519736.OF   王崇  M  20141022  交银施罗德基金  1.5  0.25  20140509
# 18    睿远成长价值A  007119.OF  傅鹏博  M  20190326     睿远基金  1.5  0.15  20190326
# 19  农银汇理新能源主题  002190.OF   赵诣  M  20190820   农银汇理基金  1.5  0.25  20160329
# 20    广发双擎升级A  005911.OF  刘格菘  M  20181102     广发基金  1.5  0.25  20181102
# 21    中欧时代先锋A  001938.OF  周应波  M  20151103     中欧基金  1.5  0.25  20151103
# 22     中欧新蓝筹A  166002.OF  周蔚文  M  20110523     中欧基金  1.5  0.25  20080725
# 23  上投摩根新兴动力A  377240.OF   杜猛  M  20110713   上投摩根基金  1.5  0.25  20110713
#
#       基金规模(亿元)    规模对应日期      2018      2019      2020      2021
# 0    17.416544  20210630 -0.271923  0.388664  0.435860 -0.088832
# 1   262.581451  20210630 -0.141935  0.699248  0.947456  0.032945
# 2    30.065539  20210630 -0.136789  0.160582  0.103410  0.080663
# 3   281.835362  20210630 -0.215530  0.561517  0.287915  0.291168
# 4   320.540966  20210630 -0.255350  0.628653  0.751603  0.016275
# 5    59.458675  20210630 -0.105123  0.203162  0.283903  0.130095
# 6   408.520506  20210630 -0.113196  0.215553  0.256741  0.002101
# 7   253.881272  20210630 -0.053947  0.195658  0.362284 -0.090734
# 8   384.198057  20210630 -0.064737  0.110949  0.140646  0.006767
# 9   898.876822  20210630 -0.052900  0.551156  0.950922 -0.126409
# 10  320.744351  20210630 -0.234663  0.713565  0.725221 -0.175389
# 11  287.010963  20210630 -0.129849  0.585684  0.715145 -0.089598
# 12    2.562304  20210630 -0.454846  0.030303 -0.037255  0.059063
# 13    5.412640  20210630 -0.373640  0.403475  0.221458  0.184685
# 14   13.871140  20210630 -0.125542  0.452676  0.508785  0.267669
# 15   13.549886  20210630 -0.215512  0.124980  0.107333 -0.010065
# 16   41.920738  20210630 -0.191889  0.238678  0.500000 -0.231884
# 17  163.332899  20210630 -0.133661  0.471841  0.487781  0.033067
# 18  330.013022  20210630       NaN  0.207500  0.709979  0.033708
# 19  199.012818  20210630 -0.344068  0.346350  1.634861  0.536823
# 20  167.212966  20210630 -0.017000  1.216887  0.643585  0.091437
# 21  210.048724  20210630 -0.083308  0.442859  0.375462  0.117924
# 22  160.265368  20210630 -0.086008  0.222090  0.209200  0.009403
# 23   63.353110  20210630 -0.356513  0.702688  0.782353  0.333854

# %%
def color_returns(val):
    if val >=0:
        color = '#EE7621' # light red 
    elif val <0:
        color = '#99ff66' # light green 
    else:
        color = '#FFFAFA' # ligth gray 
    return f'background-color: {color}'

format_dict = {'基金规模(亿元)': '￥{0:.1f}', 
               '管理费': '{0:.1f}', 
               '托管费': '{0:.2f}', 
               2017: '{0:.1%}', 
               2018: '{0:.1%}', 
               2019: '{0:.1%}', 
               2020: '{0:.1%}', 
               2021: '{0:.1%}', 
                }
df_fund_final = df_fund_final.sort_values('基金经理',ascending=True)

# df_fund_final.style.hide_index()\
#                     .hide_columns(['规模对应日期','基金公司','成立时间'])\
#                     .format(format_dict)\
#                     .background_gradient(subset=[2018],cmap='RdYlGn_r')\
#                     .background_gradient(subset=[2019],cmap='RdYlGn_r')\
#                     .background_gradient(subset=[2020],cmap='RdYlGn_r')\
#                     .background_gradient(subset=[2021],cmap='RdYlGn_r')\
#                     .background_gradient(subset=['基金规模(亿元)'],cmap='Blues')

df_fund_final.style.hide_index()\
                    .hide_columns(['规模对应日期','成立时间'])\
                    .format(format_dict)\
                    .applymap(color_returns,subset=year_list)\
                    .background_gradient(subset=['基金规模(亿元)'],cmap='Blues')
# Out:
# <style type="text/css">
# #T_7cd4e_row0_col9 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_7cd4e_row0_col11 {
#   background-color: #FFFAFA;
# }
# #T_7cd4e_row0_col12, #T_7cd4e_row0_col13, #T_7cd4e_row0_col14, #T_7cd4e_row1_col12, #T_7cd4e_row1_col13, #T_7cd4e_row2_col12, #T_7cd4e_row2_col13, #T_7cd4e_row2_col14, #T_7cd4e_row3_col12, #T_7cd4e_row3_col13, #T_7cd4e_row3_col14, #T_7cd4e_row4_col12, #T_7cd4e_row4_col13, #T_7cd4e_row4_col14, #T_7cd4e_row5_col12, #T_7cd4e_row5_col13, #T_7cd4e_row6_col12, #T_7cd4e_row6_col13, #T_7cd4e_row7_col12, #T_7cd4e_row7_col13, #T_7cd4e_row8_col12, #T_7cd4e_row8_col13, #T_7cd4e_row9_col12, #T_7cd4e_row9_col13, #T_7cd4e_row9_col14, #T_7cd4e_row10_col12, #T_7cd4e_row10_col13, #T_7cd4e_row10_col14, #T_7cd4e_row11_col12, #T_7cd4e_row11_col13, #T_7cd4e_row11_col14, #T_7cd4e_row12_col12, #T_7cd4e_row12_col13, #T_7cd4e_row12_col14, #T_7cd4e_row13_col12, #T_7cd4e_row13_col13, #T_7cd4e_row13_col14, #T_7cd4e_row14_col12, #T_7cd4e_row14_col13, #T_7cd4e_row14_col14, #T_7cd4e_row15_col12, #T_7cd4e_row15_col13, #T_7cd4e_row15_col14, #T_7cd4e_row16_col12, #T_7cd4e_row16_col13, #T_7cd4e_row17_col12, #T_7cd4e_row17_col13, #T_7cd4e_row17_col14, #T_7cd4e_row18_col12, #T_7cd4e_row18_col13, #T_7cd4e_row18_col14, #T_7cd4e_row19_col12, #T_7cd4e_row19_col13, #T_7cd4e_row19_col14, #T_7cd4e_row20_col12, #T_7cd4e_row20_col14, #T_7cd4e_row21_col12, #T_7cd4e_row21_col13, #T_7cd4e_row21_col14, #T_7cd4e_row22_col12, #T_7cd4e_row22_col13, #T_7cd4e_row22_col14, #T_7cd4e_row23_col12, #T_7cd4e_row23_col13 {
#   background-color: #EE7621;
# }
# #T_7cd4e_row1_col9 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_7cd4e_row1_col11, #T_7cd4e_row1_col14, #T_7cd4e_row2_col11, #T_7cd4e_row3_col11, #T_7cd4e_row4_col11, #T_7cd4e_row5_col11, #T_7cd4e_row5_col14, #T_7cd4e_row6_col11, #T_7cd4e_row6_col14, #T_7cd4e_row7_col11, #T_7cd4e_row7_col14, #T_7cd4e_row8_col11, #T_7cd4e_row8_col14, #T_7cd4e_row9_col11, #T_7cd4e_row10_col11, #T_7cd4e_row11_col11, #T_7cd4e_row12_col11, #T_7cd4e_row13_col11, #T_7cd4e_row14_col11, #T_7cd4e_row15_col11, #T_7cd4e_row16_col11, #T_7cd4e_row16_col14, #T_7cd4e_row17_col11, #T_7cd4e_row18_col11, #T_7cd4e_row19_col11, #T_7cd4e_row20_col11, #T_7cd4e_row20_col13, #T_7cd4e_row21_col11, #T_7cd4e_row22_col11, #T_7cd4e_row23_col11, #T_7cd4e_row23_col14 {
#   background-color: #99ff66;
# }
# #T_7cd4e_row2_col9 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_7cd4e_row3_col9 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_7cd4e_row4_col9, #T_7cd4e_row15_col9 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_7cd4e_row5_col9 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_7cd4e_row6_col9 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_7cd4e_row7_col9 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7cd4e_row8_col9, #T_7cd4e_row13_col9 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_7cd4e_row9_col9 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_7cd4e_row10_col9 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_7cd4e_row11_col9, #T_7cd4e_row20_col9 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7cd4e_row12_col9 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_7cd4e_row14_col9 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_7cd4e_row16_col9, #T_7cd4e_row21_col9 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_7cd4e_row17_col9 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_7cd4e_row18_col9 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_7cd4e_row19_col9 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_7cd4e_row22_col9 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_7cd4e_row23_col9 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# </style>
# <table id="T_7cd4e_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >基金名称</th>
#       <th class="col_heading level0 col1" >基金代码</th>
#       <th class="col_heading level0 col2" >基金经理</th>
#       <th class="col_heading level0 col3" >性别</th>
#       <th class="col_heading level0 col4" >上任日期</th>
#       <th class="col_heading level0 col5" >基金公司</th>
#       <th class="col_heading level0 col6" >管理费</th>
#       <th class="col_heading level0 col7" >托管费</th>
#       <th class="col_heading level0 col9" >基金规模(亿元)</th>
#       <th class="col_heading level0 col11" >2018</th>
#       <th class="col_heading level0 col12" >2019</th>
#       <th class="col_heading level0 col13" >2020</th>
#       <th class="col_heading level0 col14" >2021</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7cd4e_row0_col0" class="data row0 col0" >睿远成长价值A</td>
#       <td id="T_7cd4e_row0_col1" class="data row0 col1" >007119.OF</td>
#       <td id="T_7cd4e_row0_col2" class="data row0 col2" >傅鹏博</td>
#       <td id="T_7cd4e_row0_col3" class="data row0 col3" >M</td>
#       <td id="T_7cd4e_row0_col4" class="data row0 col4" >20190326</td>
#       <td id="T_7cd4e_row0_col5" class="data row0 col5" >睿远基金</td>
#       <td id="T_7cd4e_row0_col6" class="data row0 col6" >1.5</td>
#       <td id="T_7cd4e_row0_col7" class="data row0 col7" >0.15</td>
#       <td id="T_7cd4e_row0_col9" class="data row0 col9" >￥330.0</td>
#       <td id="T_7cd4e_row0_col11" class="data row0 col11" >nan%</td>
#       <td id="T_7cd4e_row0_col12" class="data row0 col12" >20.8%</td>
#       <td id="T_7cd4e_row0_col13" class="data row0 col13" >71.0%</td>
#       <td id="T_7cd4e_row0_col14" class="data row0 col14" >3.4%</td>
#     </tr>
#     <tr>
#       <td id="T_7cd4e_row1_col0" class="data row1 col0" >景顺鼎益</td>
#       <td id="T_7cd4e_row1_col1" class="data row1 col1" >162605.SZ</td>
#       <td id="T_7cd4e_row1_col2" class="data row1 col2" >刘彦春</td>
#       <td id="T_7cd4e_row1_col3" class="data row1 col3" >M</td>
#       <td id="T_7cd4e_row1_col4" class="data row1 col4" >20150710</td>
#       <td id="T_7cd4e_row1_col5" class="data row1 col5" >景顺长城基金</td>
#       <td id="T_7cd4e_row1_col6" class="data row1 col6" >1.5</td>
#       <td id="T_7cd4e_row1_col7" class="data row1 col7" >0.25</td>
#       <td id="T_7cd4e_row1_col9" class="data row1 col9" >￥253.9</td>
#       <td id="T_7cd4e_row1_col11" class="data row1 col11" >-5.4%</td>
#       <td id="T_7cd4e_row1_col12" class="data row1 col12" >19.6%</td>
#       <td id="T_7cd4e_row1_col13" class="data row1 col13" >36.2%</td>
#       <td id="T_7cd4e_row1_col14" class="data row1 col14" >-9.1%</td>
#     </tr>
#     <tr>
#       <td id="T_7cd4e_row2_col0" class="data row2 col0" >广发双擎升级A</td>
#       <td id="T_7cd4e_row2_col1" class="data row2 col1" >005911.OF</td>
#       <td id="T_7cd4e_row2_col2" class="data row2 col2" >刘格菘</td>
#       <td id="T_7cd4e_row2_col3" class="data row2 col3" >M</td>
#       <td id="T_7cd4e_row2_col4" class="data row2 col4" >20181102</td>
#       <td id="T_7cd4e_row2_col5" class="data row2 col5" >广发基金</td>
#       <td id="T_7cd4e_row2_col6" class="data row2 col6" >1.5</td>
#       <td id="T_7cd4e_row2_col7" class="data row2 col7" >0.25</td>
#       <td id="T_7cd4e_row2_col9" class="data row2 col9" >￥167.2</td>
#       <td id="T_7cd4e_row2_col11" class="data row2 col11" >-1.7%</td>
#       <td id="T_7cd4e_row2_col12" class="data row2 col12" >121.7%</td>
#       <td id="T_7cd4e_row2_col13" class="data row2 col13" >64.4%</td>
#       <td id="T_7cd4e_row2_col14" class="data row2 col14" >9.1%</td>
#     </tr>
#     <tr>
#       <td id="T_7cd4e_row3_col0" class="data row3 col0" >中欧时代先锋A</td>
#       <td id="T_7cd4e_row3_col1" class="data row3 col1" >001938.OF</td>
#       <td id="T_7cd4e_row3_col2" class="data row3 col2" >周应波</td>
#       <td id="T_7cd4e_row3_col3" class="data row3 col3" >M</td>
#       <td id="T_7cd4e_row3_col4" class="data row3 col4" >20151103</td>
#       <td id="T_7cd4e_row3_col5" class="data row3 col5" >中欧基金</td>
#       <td id="T_7cd4e_row3_col6" class="data row3 col6" >1.5</td>
#       <td id="T_7cd4e_row3_col7" class="data row3 col7" >0.25</td>
#       <td id="T_7cd4e_row3_col9" class="data row3 col9" >￥210.0</td>
#       <td id="T_7cd4e_row3_col11" class="data row3 col11" >-8.3%</td>
#       <td id="T_7cd4e_row3_col12" class="data row3 col12" >44.3%</td>
#       <td id="T_7cd4e_row3_col13" class="data row

# %% [markdown]
# ## 相关阅读
#
# - [视频：Plotly 和 Dash 在投资领域的应用](https://mp.weixin.qq.com/s/VopPrpe_64j5za4AYkmUTg)
#
# - [视频：Plotly中绘制股票交易图表](https://mp.weixin.qq.com/s/1TUB2G-xavNm796uXUnRfQ)
#
# - [Plotly中绘制三种经典的股票交易图表](https://mp.weixin.qq.com/s/1v3h5-5fNVk7cBdaRKzJkg)
#
# - [神器Tushare，财经数据必备工具！](https://mp.weixin.qq.com/s/c1ukemeK12flCgA-lo69fA)
#
# - [股票亏惨了，用Python来做一个投资计划](https://mp.weixin.qq.com/s/WYuMwCJBrWaBiDs8xp2KMA)
#
# - [用 Python 读取巴菲特近期持仓数据](https://mp.weixin.qq.com/s/6h9Xq2lfrZSlRNw_W8aWcg)
#
# 更多内容，请关注公众号「**Python数据之道**」：
#
# ![](https://tva1.sinaimg.cn/large/008i3skNgy1gs2d9ca7dvj31hc0u07ng.jpg)
